# %% [markdown]
# # INF-475
# ## Tarea 2
# ### Daniel San Martín

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.style.use('bmh')
np.random.seed(666)

# %% [markdown]
# ### Exploración de los datos

# %% [markdown]
# Cargamos los datos, revisamos estadísticas generales y un gráfico de la serie.

# %%
df = pd.read_csv('data/river_flows.csv', header=None, names=['date', 'flows'])

# %%
df.head()
# Out:
#          date  flows
# 0  1913-01-31    485
# 1  1913-02-28   1150
# 2  1913-03-31   4990
# 3  1913-04-30   6130
# 4  1913-05-31   4780

# %%
df.describe()
# Out:
#               flows
# count    946.000000
# mean    2708.573996
# std     2123.234239
# min      482.000000
# 25%     1010.000000
# 50%     1915.000000
# 75%     3947.500000
# max    10800.000000

# %%
df.plot()
plt.show()

# %% [markdown]
# #### Modelo Ingenuo

# %% [markdown]
# Realizamos una descomposición de la serie, suponiendo un modelo ingenuo aditivo.

# %%
decomposition = seasonal_decompose(df['flows'].values, model='additive', freq=12)
fig = decomposition.plot()
fig.set_size_inches(15,10)
plt.plot()
# Out:
# []

# %% [markdown]
# Lamentablemente notamos que no existen una tendencia "lineal" que pudiera ayudarnos a facilitar el análisis de la serie.

# %% [markdown]
# #### Gráficos de Autocorrelación y Autocorrelación Parcial

# %%
plot_acf(df['flows'], lags=50)
plt.show()

# %%
plot_pacf(df['flows'], lags=50)
plt.show()

# %% [markdown]
# ## Buscar tendencia

# %%
from scipy import stats

y = df['flows']#.values
x = np.array(range(1, len(y) + 1))
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y.values)

# %%
trend = pd.Series(map(lambda x: x*slope + intercept, x), df['date'])
y.plot()
trend.plot(style='--')
plt.xlabel('Price Index')
plt.ylabel('Time')
plt.show()

# %%
diff_serie = pd.Series(np.diff(y, n=12))

# %%
plot_acf(diff_serie, lags=50)
plt.show()

# %%
plot_pacf(diff_serie, lags=50)
plt.show()

# %%
from pandas import concat
from pandas.plotting import scatter_matrix
values = pd.DataFrame(y.values)
lags = 12
columns = [values]
for i in range(1,(lags + 1)):
    columns.append(values.shift(i))
dataframe = concat(columns, axis=1)
columns = ['t+1']
for i in range(1,(lags + 1)):
    columns.append('t-' + str(i))
dataframe.columns = columns
plt.figure(1, figsize=(20,10))
for i in range(1,(lags + 1)):
    ax = plt.subplot(3, 4, i)#plt.subplot(340 + i)
    ax.set_title('t+1 vs t-' + str(i))
    plt.scatter(x=dataframe['t+1'].values, y=dataframe['t-'+str(i)].values)
plt.show()
